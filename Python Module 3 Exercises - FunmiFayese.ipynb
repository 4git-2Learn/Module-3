# %% [markdown]
# Exercise 1. Ask for a color and store that answer.
# If the answer is grey then print out you found Victor's favorite color.
# Otherwise print out the color is not Victor's favorite color.

# %%
fav_color = input("Enter your favorite color: ")
if fav_color == "grey" :
    print("I have found Victor's favorite color: ", fav_color)
else :
    print("This color is not Victor's favorite color")
# Out:
# Enter your favorite color: grey
# I have found Victor's favorite color:  grey

# %% [markdown]
# Exercise 2. Modify code from above exercise 1 and add in more conditions for other colors such as red, green, blue and then, write statements for them.

# %%
#pring Victor's favorite color = "grey"
fav_color = input("Enter your favorite color: ")
if fav_color == "grey" :
    print("I have found Victor's favorite color: ", fav_color)
elif fav_color == "red" :
    print("red is not Victor's favorite color")
elif fav_color == "green" :
    print("green is not Victor's favorite color")
elif fav_color == "blue" :
    print("blue is not Victor's favorite color")
elif fav_color == "white" :
    print("while is not Victor's favorite color")
else :
    print("Stop")
# Out:
# Enter your favorite color: grey
# I have found Victor's favorite color:  grey

# %% [markdown]
# Exercise 3. Ask for an exam score and store that number. If the number is greater than 100, then print out 'You cannot have an exam score higher than 100'. If the number doesn't exceeed 100 but is greater than or equal to 75, then print out 'You did great on your exam!'. Otherwise if they scored lower than 75, then print out 'You need to study harder'.

# %%
score = int(input("Enter your exam score: "))
if score > 100 :
    print ("You cannot have an exam score higher than 100")
elif score >= 75 :
    print("You did great on your exam!")
elif score < 75 :
    print("You need to study harder")
else :
        
    print("Stop")
# Out:
# Enter your exam score: 70
# You need to study harder

# %% [markdown]
# Exercise 4.
# Define two functions:
#     - a function that takes 3 arguements and returns the sum of three arguements
#     - a function that takes 2 arguements and returns the result of 1st arguement multiplied by 2nd arguement
#
# Then tell the user to choose option 1 to add three numbers or option 2 to multiply two numbers.
# If the user choose option 1 then call the addition function, otherwise if they choose option 2 then call the mulitplication function.  If the user choose anything other than option 1 or 2, then generate a friendly error messsage

# %%
import sys
def numbers(param1, param2, param3) :
    option = int(input("Choose your option: "))
    if option == 1 :
        print(f"add three numbers :", param1+param2+param3)
    elif option ==2 :
        print (f"multipy two numbers :", param1*param2)
           
    elif option ==3 :
        print("***ERROR: ", sys.exc_info()[0], "option is invalid.")
        retval = 0
        
           
numbers(5, 2, 5)
# Out:
# Choose your option: 3
# ***ERROR:  None option is invalid.

# %% [markdown]
# Exercise 5.
# Write a function to convert a test score to a grade where
#  - 90 - 100: A
#  - 80 - 89:  B
#  - 70 - 79:  C
#  - 60 - 69:  D
#  - < 60   :  F
#
# If a score is not between 0 and 100 then print out an error message. In the program, ask the user for a score and then call your function.

# %%
def convert_score(start, end) :
    score = int(input("Enter your score: "))
    if score >=90 :
        print(f"Grade is :", "A")
    elif score >=80 :
        print (f"Grade is: ", "B")
           
    elif score >=70 :
        print(f"Grade is :", "C")
    elif score >=60 :
        print(f"Grade is :", "D")
    elif score < 60 :
        print(f"Grade is :", "F")
    else :
        print("***ERROR: invalid score entered.")
               
convert_score(0, 100)
# Out:
# Enter your score: 100
# Grade is : A

# %% [markdown]
# Exercise 6. Write a program to compute discounts for customers.
# - For retail customers,
#     - if invoice total is greater than \$100 then discount rate is 10\%, otherwise no discount
#
# - For wholesale customers,
#     - if invoice total is greater than \$500 then discount rate is 30\%, otherwise discount rate is 20\%
#
# Get the type of customer and the invoice total from the user.

# %% [markdown]
# def cust_discount() :
#     cust_type = str(input("Enter customer type : "))
#     inv_total = int(input("Enter your total invoice : "))
#     if cust_type == "retail" and  inv_total > 100 :
#         print(f"Customer Type is : ", cust_type, ",", "New Discount is: ", inv_total * 0.1)
#     else :
#         print(f"New Discount is: ", "none")
#     if cust_type == "wholesale" and inv_total > 500 :
#         print (f"Customer Type is : ", cust_type, ",", "New Discount is: ", inv_total * 0.3)
#     else :
#         print(f"Customer Type is : ", cust_type, ",", "New Discount is: ", inv_total * 0.2)
#
# cust_discount()

# %% [markdown]
# Exercise 7: Write a function that accepts two parameters (a and b) and returns a result of a/b.  In this function, try to catch any exception error.  Then, write a program to get two numbers from a user, call your function using these two numbers, and print out the result in a friendly format.  All input and print statements must be done in the main program. Repeat the process until user wants to quit the program.

# %%
def numbers(val1, val2) :
    val1 = int(input("\nEnter the first number: "))
    val2 = int(input("\nEnter the second number: "))
    retval = float(val1/val2)
    print(f"Result of param1 divide by param2 = ", retval)
    while True:
        choice = input("\nDo you want to check again? (y/n): ")
        if (choice.lower() != 'y') :
            print(f"Bye!")
            break
        else:
            print(f"Good job")

numbers(1, 100)
# Out:
# Enter the first number: 10
#
# Enter the second number: 5
# Result of param1 divide by param2 =  2.0
#
# Do you want to check again? (y/n): n
# Bye!

# %% [markdown]
# Exercise 8: Write a function to generate a multiplication table. Then write a program to ask a user if user wants to generate a  mutiplication table for a random number or provide a number. The program should continue to run until a user wants to quit.

# %%
def multiply_table() :
    num = int(input("Enter a number: "))
    print(num,"*",1,"=",num * 1) 
    print(num,"*",2,"=",num * 2)
    print(num,"*",3,"=",num * 3)
    print(num,"*",4,"=",num * 4)
    print(num,"*",5,"=",num * 5)
    print(num,"*",6,"=",num * 6)
    print(num,"*",7,"=",num * 7)
    print(num,"*",8,"=",num * 8)
    print(num,"*",9,"=",num * 9)
    return

multiply_table()

# %%
import random as rand
rand.randint(1, 10)
def multiply_table() :
    while True:
        choice = input("\nGenerate a number? (random number/provide a number): ")
        if (choice.lower() != 'random number') :
            num = int(input("Enter a number: "))
            print(num,"*",1,"=",num * 1) 
            print(num,"*",2,"=",num * 2)
            print(num,"*",3,"=",num * 3)
            print(num,"*",4,"=",num * 4)
            print(num,"*",5,"=",num * 5)
            print(num,"*",6,"=",num * 6)
            print(num,"*",7,"=",num * 7)
            print(num,"*",8,"=",num * 8)
            print(num,"*",9,"=",num * 9)
            return
        elif (choice.lower() == 'random number') :
            x = rand.randint(1,10)
            print(x,"*",1,"=",x * 1) 
            print(x,"*",2,"=",x * 2)
            print(x,"*",3,"=",x * 3)
            print(x,"*",4,"=",x * 4)
            print(x,"*",5,"=",x * 5)
            print(x,"*",6,"=",x * 6)
            print(x,"*",7,"=",x * 7)
            print(x,"*",8,"=",x * 8)
            print(x,"*",9,"=",x * 9)
            return
        else:
            choice = input("\nDo you want to check again? (y/n): ")
            if (choice.lower() != 'y') :
                print(f"Bye!")
                break
            else:
                print(f"Good job")            

multiply_table()
# Out:
# Generate a number? (random number/provide a number): random number
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27

# %% [markdown]
# Exercise 9: Write a function to draw a right-triangle using a number as a character.Then, write a program to generate a random number between 1 and 9, call your function with that random number.  The output should look something like this:
#
#         base: 5
#         5
#         55
#         555
#         5555
#         55555
#
#
#         base: 8
#         8
#         88
#         888
#         8888
#         88888
#         888888
#         8888888
#         88888888

# %%
import random as rand
rand.randint(1, 10)
def function_draw(start, end) :
    x = rand.randint(1,10)
    str_num = str(x)
    print(f"", str_num)
    print(f"", str_num*2)
    print(f"", str_num*3)
    print(f"", str_num*4)
    print(f"", str_num*5)
    print(f"", str_num*6)
    print(f"", str_num*7)
    print(f"", str_num*8)
    print(f"", str_num*9)
   
function_draw(1, 10)
# Out:
#  9
#  99
#  999
#  9999
#  99999
#  999999
#  9999999
#  99999999
#  999999999

# %% [markdown]
# Exercise 10: Modify function from exercise 9 to show output like this:
#
#         base: 5
#             5
#            55
#           555
#          5555
#         55555
#
#         base: 8
#                8
#               88
#              888
#             8888
#            88888
#           888888
#          8888888
#         88888888

# %%
import random as rand
rand.randint(1, 10)
def function_draw(start, end) :
    x = rand.randint(1,10)
    width = 10
    print("Base: ", x)
    print(""+"{:10d}".format(x))
    print(""+"{:10d}".format(x**2))
    print(""+"{:10d}".format(x**3))
    print(""+"{:10d}".format(x**4))
    print(""+"{:10d}".format(x**5))
    print(""+"{:10d}".format(x**6))
    print(""+"{:10d}".format(x**7))
    print(""+"{:10d}".format(x**8))
    print(""+"{:10d}".format(x**9))
    
function_draw(1, 10)
# Out:
# Base:  7
#          7
#         49
#        343
#       2401
#      16807
#     117649
#     823543
#    5764801
#   40353607
